# %%
# Get the current working directory

# %%
# !pwd
# Out:
# /home/jack/Desktop/StoryMaker

# %%
# !ls
# Out:
#  8007c650-65e4-46de-90bf-a1b21b10344bTEMP_MPY_wvf_snd.mp3
#  a26de673-752e-4ec2-9659-5bb7c342275aTEMP_MPY_wvf_snd.mp3
#  a65f36bf-994c-4b34-801a-9bfa3b1b48eeTEMP_MPY_wvf_snd.mp3
#  abd0aebb-ce72-4a30-a233-14ee14f5b841random_video_58sTEMP_MPY_wvf_snd.mp3
#  animate
#  app.log
#  app-old.py
#  app_problem.py
#  app.py
#  app_resource.py
#  app_workinggreat.py
#  audio.py
#  audio.wav
#  back
#  background.png
#  BlackFORMATTED.png
#  chat.txt
#  checkpoints
#  circle_blur_mouth.ipynb
#  clean_images
#  clean_images.py
#  clip_12TEMP_MPY_wvf_snd.mp3
#  clip_27TEMP_MPY_wvf_snd.mp3
#  CODE
#  code.db
#  color_syncnet_train.py
#  create_db.py
#  Create_Ipython_Kernel_of_your_Flask_env.ipynb
#  CurrentProject
#  database-o.db
#  database.py
#  directory_structure.txt
#  env
#  error_log.txt
#  evaluation
#  EXP_database.py
#  exp.py
#  face_detection
#  favicon.ico
#  foreground.png
#  FORMATTED.txt
#  gifs
#  hparams.py
#  hq_wav2lip_train.py
#  Imports_moviepy-ffmpeg-Copy1.ipynb
# ...
